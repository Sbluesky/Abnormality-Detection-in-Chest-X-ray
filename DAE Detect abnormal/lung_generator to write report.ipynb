# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Study/DL main project
# Out:
# /content/drive/MyDrive/Study/DL main project

# %% [markdown]
# # Visualize data

# %%
# def get_img_position_vector(img,chanels):
#     X = None
    
#     #### YOUR CODE HERE ####
#     # X_x = np.array([np.arange(img.shape[0]) for i in range(img.shape[1])])
#     # X_y = np.array([np.arange(img.shape[1]) for i in range(img.shape[0])]).T
#     # X = np.hstack([img.reshape((-1,3)),X_x.reshape((-1,1)),X_y.reshape((-1,1))])
#     #Code mẫu
#     X = img.reshape(-1,chanels)
#     x_inds = np.arange(img.shape[0])
#     y_inds = np.arange(img.shape[1])
#     X_pos = np.stack(np.meshgrid(x_inds,y_inds)).T
#     X_pos = X_pos.reshape(-1,2)    
#     X = np.concatenate((X,X_pos),axis=1)
#     #### END YOUR CODE #####
    
#     return X

# %%
# path = './train/lung/14/001/0d713a8274dc92be9a75639d9b6558e1.png'
# img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
# img = 255 - cv2.resize(img,(512,512))
# img_flatten = get_img_position_vector(img,1)
# z = img_flatten[:,1:3]
# x = img_flatten[:,0:2]
# y = img_flatten[:,[0,2]]
# fig = plt.figure()
# ax = plt.axes(projection='3d')
# ax.view_init(80, -60)
# ax.scatter3D(img_flatten[:,1], img_flatten[:,2], img_flatten[:,0], c=img_flatten[:,0], cmap='Greens')

# %% [markdown]
# # **IMPORT LIBRARIES**

# %%
import os

import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler

from glob import glob
from process_data_v2 import ProcessData
from tqdm.auto import tqdm

# %%
from keras.models import load_model

# %% [markdown]
# # **Load Data**

# %%
csv_path = './csv'
img_load_dir = './train/png'
lung_load_dir = './train/lung'
mask_load_dir = './train/mask'

# make process variable
pdata = ProcessData(seed=42)

# %% [markdown]
# # **Load lung and mask**

# %%
class_name ='14'
batch_name ='001'

class_csv_path = os.path.join(csv_path,class_name,batch_name+'.csv')
class_lung_load_dir = os.path.join(lung_load_dir,class_name,batch_name)
class_mask_load_dir = os.path.join(mask_load_dir,class_name,batch_name)

img_names = pdata.get_img_names(class_csv_path)
mask_size, masks = pdata.get_masks(img_names,class_mask_load_dir, size=(112,112))
lungs = pdata.get_imgs(img_names,class_lung_load_dir,size=mask_size)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='load_mask', max=150.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='load_img', max=150.0, style=ProgressStyle(description_wid…

# %%
def duplicate_data(data,size):
  temp = np.vstack([data,data])  
  for i in range(size):
    temp = np.vstack([temp,data])
  return temp

# %%
lungs = duplicate_data(lungs,10)
masks = duplicate_data(masks,10)
lungs.shape, masks.shape
# Out:
# ((1800, 112, 112, 1), (1800, 112, 112, 1))

# %%
data_noise_snow = pdata.get_data_noise(lungs,masks,ntype=2)[:,:,:,:1].astype(np.uint8)
# data_noise_drop.shape, 
data_noise_snow.shape
# Out:
# HBox(children=(FloatProgress(value=0.0, description='noise_type_02', max=1800.0, style=ProgressStyle(descripti…
# (1800, 112, 112, 1)

# %% [markdown]
# # **Process Data**

# %% [markdown]
# ## **Model**

# %%
# import the necessary packages
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D, UpSampling2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import numpy as np

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2

# %% [markdown]
# ### **Model 1**

# %%
# https://www.pyimagesearch.com/2020/02/24/denoising-autoencoders-with-keras-tensorflow-and-deep-learning/
def dae_build(inputShape, activation='sigmoid',filters=(32, 64), latentDim=256):
		# initialize the input shape to be "channels last" along with
		# the channels dimension itself
		# channels dimension itself
		(height, width, depth) = inputShape
		chanDim = -1
		# define the input to the encoder
		inputs = Input(shape=inputShape)
		x = inputs

    # loop over the number of filters
		for f in filters:
			# apply a CONV => RELU => BN operation
			x = Conv2D(f, (3, 3), strides=2, padding="same")(x)
			x = LeakyReLU(alpha=0.2)(x)
			x = BatchNormalization(axis=chanDim)(x)
		# flatten the network and then construct our latent vector
		volumeSize = K.int_shape(x)
		x = Flatten()(x)
		latent = Dense(latentDim)(x)
		# build the encoder model
		encoder = Model(inputs, latent, name="encoder")
  
    # start building the decoder model which will accept the
		# output of the encoder as its inputs
		latentInputs = Input(shape=(latentDim,))
		x = Dense(np.prod(volumeSize[1:]))(latentInputs)
		x = Reshape((volumeSize[1], volumeSize[2], volumeSize[3]))(x)
		# loop over our number of filters again, but this time in
		# reverse order
		for f in filters[::-1]:
			# apply a CONV_TRANSPOSE => RELU => BN operation
			x = Conv2DTranspose(f, (3, 3), strides=2,
				padding="same")(x)
			x = LeakyReLU(alpha=0.2)(x)
			x = BatchNormalization(axis=chanDim)(x)
		# apply a single CONV_TRANSPOSE layer used to recover the
		# original depth of the image
		x = Conv2DTranspose(depth, (3, 3), padding="same")(x)
		outputs = Activation(activation)(x)
		# build the decoder model
		decoder = Model(latentInputs, outputs, name="decoder")
		# our autoencoder is the encoder + decoder
		autoencoder = Model(inputs, decoder(encoder(inputs)), name="autoencoder")
		# return a 3-tuple of the encoder, decoder, and autoencoder
		return (encoder, decoder, autoencoder)

# %% [markdown]
# ### **Model 2**

# %%
def dae_build(width, height, depth):
  # initialize the input shape to be "channels last" along with
  # the channels dimension itself
  # channels dimension itself
  inputShape = (height, width, depth)		
  inputs = Input(shape=inputShape)
  x = inputs
  x = Conv2D(64,kernel_size=(3,3),padding='same',activation='relu')(x)
  x = MaxPool2D((2,2),strides=2)(x)
  x = Conv2D(64,kernel_size=(3,3),padding='same',activation='relu')(x)
  x = MaxPool2D((2,2),strides=2)(x)

  x = Conv2D(64,kernel_size=(3,3),padding='same',activation='relu')(x)
  x = UpSampling2D((2,2))(x)
  x = Conv2D(64,kernel_size=(3,3),padding='same',activation='relu')(x)
  x = UpSampling2D((2,2))(x)

  x = Conv2D(1,kernel_size=(3,3),padding='same',activation='sigmoid')(x)
  autoencoder = Model(inputs, x, name="autoencoder")
  # return a 3-tuple of the encoder, decoder, and autoencoder
  return autoencoder

# %% [markdown]
# ## type 01: Dropout noise

# %% [markdown]
# ### View

# %%
data_noise_drop = pdata.get_data_noise(lungs,masks,ntype=1).astype(np.uint8)
data_noise_drop.shape
# Out:
# HBox(children=(FloatProgress(value=0.0, description='noise_type_01', max=1800.0, style=ProgressStyle(descripti…
# (1800, 112, 112, 1)

# %%
plt.imshow(data_noise_drop[0,:,:,0],cmap='gray')

# %% [markdown]
# ### Build

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(data_noise_drop,lungs,test_size=0.25,random_state=42)

# %%
EPOCHS = 100
BS = 5
(encoder, decoder, autoencoder) = dae_build(data[0].shape,activation='relu')
# autoencoder = dae_build(data[0].shape[0],data[0].shape[1],data[0].shape[2])
opt = Adam(lr=1e-3)
autoencoder.compile(loss="mse", optimizer=opt)
# train the convolutional autoencoder
H = autoencoder.fit(
	xtrain, ytrain,
	validation_data=(xtest, ytest),
	epochs=EPOCHS,
	batch_size=BS)
# construct a plot that plots and saves the training history
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
# Out:
# Epoch 1/100
# 270/270 [==============================] - 4s 13ms/step - loss: 2152.0432 - val_loss: 754.4210
# Epoch 2/100
# 270/270 [==============================] - 3s 12ms/step - loss: 656.3695 - val_loss: 557.6857
# Epoch 3/100
# 270/270 [==============================] - 3s 13ms/step - loss: 467.2178 - val_loss: 435.5172
# Epoch 4/100
# 270/270 [==============================] - 3s 12ms/step - loss: 325.9270 - val_loss: 365.7451
# Epoch 5/100
# 270/270 [==============================] - 3s 12ms/step - loss: 237.3126 - val_loss: 226.3736
# Epoch 6/100
# 270/270 [==============================] - 3s 12ms/step - loss: 171.2325 - val_loss: 173.2432
# Epoch 7/100
# 270/270 [==============================] - 3s 12ms/step - loss: 122.0045 - val_loss: 150.4706
# Epoch 8/100
# 270/270 [==============================] - 3s 12ms/step - loss: 95.0268 - val_loss: 120.8542
# Epoch 9/100
# 270/270 [==============================] - 3s 12ms/step - loss: 76.8861 - val_loss: 107.2990
# Epoch 10/100
# 270/270 [==============================] - 3s 12ms/step - loss: 61.8773 - val_loss: 81.2045
# Epoch 11/100
# 270/270 [==============================] - 3s 12ms/step - loss: 49.1493 - val_loss: 71.4868
# Epoch 12/100
# 270/270 [==============================] - 3s 12ms/step - loss: 39.7605 - val_loss: 55.8095
# Epoch 13/100
# 270/270 [==============================] - 3s 12ms/step - loss: 33.1569 - val_loss: 53.6528
# Epoch 14/100
# 270/270 [==============================] - 3s 12ms/step - loss: 24.0183 - val_loss: 42.9445
# Epoch 15/100
# 270/270 [==============================] - 3s 12ms/step - loss: 27.9709 - val_loss: 38.7270
# Epoch 16/100
# 270/270 [==============================] - 3s 12ms/step - loss: 17.3983 - val_loss: 43.0974
# Epoch 17/100
# 270/270 [==============================] - 3s 12ms/step - loss: 14.2684 - val_loss: 29.6174
# Epoch 18/100
# 270/270 [==============================] - 3s 12ms/step - loss: 11.5954 - val_loss: 29.8492
# Epoch 19/100
# 270/270 [==============================] - 3s 12ms/step - loss: 10.0927 - val_loss: 34.0202
# Epoch 20/100
# 270/270 [==============================] - 3s 12ms/step - loss: 9.5262 - val_loss: 29.9898
# Epoch 21/100
# 270/270 [==============================] - 3s 12ms/step - loss: 10.7824 - val_loss: 71.5994
# Epoch 22/100
# 270/270 [==============================] - 3s 12ms/step - loss: 24.9254 - val_loss: 31.0447
# Epoch 23/100
# 270/270 [==============================] - 3s 12ms/step - loss: 10.3681 - val_loss: 25.8648
# Epoch 24/100
# 270/270 [==============================] - 3s 12ms/step - loss: 7.8155 - val_loss: 23.3900
# Epoch 25/100
# 270/270 [==============================] - 3s 12ms/step - loss: 6.4175 - val_loss: 22.4069
# Epoch 26/100
# 270/270 [==============================] - 3s 12ms/step - loss: 5.9778 - val_loss: 25.1115
# Epoch 27/100
# 270/270 [==============================] - 3s 12ms/step - loss: 6.1568 - val_loss: 21.5620
# Epoch 28/100
# 270/270 [==============================] - 3s 12ms/step - loss: 5.3955 - val_loss: 20.5403
# Epoch 29/100
# 270/270 [==============================] - 3s 12ms/step - loss: 5.0137 - val_loss: 21.6097
# Epoch 30/100
# 270/270 [==============================] - 3s 12ms/step - loss: 6.6924 - val_loss: 23.1011
# Epoch 31/100
# 270/270 [==============================] - 3s 12ms/step - loss: 6.7646 - val_loss: 21.0397
# Epoch 32/100
# 270/270 [==============================] - 3s 12ms/step - loss: 10.4071 - val_loss: 21.4372
# Epoch 33/100
# 270/270 [==============================] - 3s 12ms/step - loss: 6.8562 - val_loss: 21.7268
# Epoch 34/100
# 270/270 [==============================] - 3s 12ms/step - loss: 5.4205 - val_loss: 19.6044
# Epoch 35/100
# 270/270 [==============================] - 3s 12ms/step - loss: 4.0920 - val_loss: 17.6469
# Epoch 36/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.7780 - val_loss: 17.0141
# Epoch 37/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.2923 - val_loss: 17.4796
# Epoch 38/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.9610 - val_loss: 23.1434
# Epoch 39/100
# 270/270 [==============================] - 3s 12ms/step - loss: 5.9515 - val_loss: 21.9709
# Epoch 40/100
# 270/270 [==============================] - 3s 12ms/step - loss: 5.5899 - val_loss: 18.6996
# Epoch 41/100
# 270/270 [==============================] - 3s 12ms/step - loss: 4.4357 - val_loss: 17.5420
# Epoch 42/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.2151 - val_loss: 19.3553
# Epoch 43/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.2380 - val_loss: 16.4007
# Epoch 44/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.4851 - val_loss: 16.1867
# Epoch 45/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.2582 - val_loss: 17.4208
# Epoch 46/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.2183 - val_loss: 16.2054
# Epoch 47/100
# 270/270 [==============================] - 3s 12ms/step - loss: 6.5093 - val_loss: 35.3634
# Epoch 48/100
# 270/270 [==============================] - 3s 12ms/step - loss: 8.4910 - val_loss: 16.4312
# Epoch 49/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.8006 - val_loss: 15.6944
# Epoch 50/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.8170 - val_loss: 17.1067
# Epoch 51/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.9500 - val_loss: 15.4724
# Epoch 52/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.8980 - val_loss: 16.9091
# Epoch 53/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.2168 - val_loss: 15.8095
# Epoch 54/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.0810 - val_loss: 15.9884
# Epoch 55/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.0715 - val_loss: 16.2491
# Epoch 56/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.1967 - val_loss: 15.6599
# Epoch 57/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.3653 - val_loss: 15.1801
# Epoch 58/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.2555 - val_loss: 16.3683
# Epoch 59/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.8729 - val_loss: 17.8327
# Epoch 60/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.2430 - val_loss: 17.8032
# Epoch 61/100
# 270/270 [==============================] - 3s 13ms/step - loss: 3.1521 - val_loss: 14.5789
# Epoch 62/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.9461 - val_loss: 13.8671
# Epoch 63/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.7293 - val_loss: 14.7056
# Epoch 64/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.2170 - val_loss: 15.5562
# Epoch 65/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.8418 - val_loss: 15.5383
# Epoch 66/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.0434 - val_loss: 14.4365
# Epoch 67/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.4086 - val_loss: 17.3096
# Epoch 68/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.4559 - val_loss: 15.4691
# Epoch 69/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.1648 - val_loss: 13.9991
# Epoch 70/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.2906 - val_loss: 13.9909
# Epoch 71/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.8556 - val_loss: 14.0381
# Epoch 72/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.7837 - val_loss: 15.4798
# Epoch 73/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.6356 - val_loss: 15.5963
# Epoch 74/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.3096 - val_loss: 13.9117
# Epoch 75/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.5857 - val_loss: 15.7062
# Epoch 76/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.0981 - val_loss: 13.7289
# Epoch 77/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.6607 - val_loss: 13.4733
# Epoch 78/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.2365 - val_loss: 14.0159
# Epoch 79/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.9817 - val_loss: 13.2566
# Epoch 80/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0571 - val_loss: 14.0848
# Epoch 81/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.1171 - val_loss: 13.9124
# Epoch 82/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.4897 - val_loss: 14.3920
# Epoch 83/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.6196 - val_loss: 14.4742
# Epoch 84/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.3825 - val_loss: 13.8246
# Epoch 85/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.2662 - val_loss: 14.4139
# Epoch 86/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.4195 - val_loss: 13.9273
# Epoch 87/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.4562 - val_loss: 15.5962
# Epoch 88/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.5173 - val_loss: 14.8759
# Epoch 89/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.7563 - val_loss: 14.2926
# Epoch 90/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.1506 - val_loss: 14.4955
# Epoch 91/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.2990 - val_loss: 13.7394
# Epoch 92/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0355 - val_loss: 14.5316
# Epoch 93/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.4504 - val_loss: 13.3726
# Epoch 94/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0178 - val_loss: 14.2464
# Epoch 95/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.9972 - val_loss: 15.2178
# Epoch 96/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.1310 - val_loss: 14.6156
# Epoch 97/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.3952 - val_loss: 13.9396
# Epoch 98/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.7599 - val_loss: 13.2835
# Epoch 99/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.2131 - val_loss: 13.2437
# Epoch 100/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.9128 - val_loss: 13.7285

# %% [markdown]
# ### Kiểm thử dữ liệu train

# %%
test = autoencoder.predict(data_noise_drop[:10])

# %%
plt.imshow(data_noise_drop[0,:,:,0],cmap='gray')

# %%
plt.imshow(test[0,:,:,0],cmap='gray')

# %%
plt.imshow(data[0,:,:,0],cmap='gray')

# %%
plt.plot(np.arange(0,112),data[0,40,:,0])

# %%
plt.plot(np.arange(0,112),test[0,40,:,0])

# %%
plt.plot(np.arange(0,112),data_noise_drop[0,40,:,0])

# %% [markdown]
# ### Kiểm thử trên dữ liệu mới

# %%
class_name ='14'
batch_name ='000'

class_csv_path = os.path.join(csv_path,class_name,batch_name+'.csv')
class_lung_load_dir = os.path.join(lung_load_dir,class_name,batch_name)
class_mask_load_dir = os.path.join(mask_load_dir,class_name,batch_name)

img_names = pdata.get_img_names(class_csv_path)
mask_size, masks = pdata.get_masks(img_names,class_mask_load_dir, size=(112,112))
lungs = pdata.get_imgs(img_names,class_lung_load_dir,size=mask_size)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='load_mask', max=96.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='load_img', max=96.0, style=ProgressStyle(description_widt…

# %%
data_noise_drop = pdata.get_data_noise(lungs,masks,ntype=1).astype(np.uint8)
data_noise_drop.shape
# Out:
# HBox(children=(FloatProgress(value=0.0, description='noise_type_01', max=96.0, style=ProgressStyle(description…
# (96, 112, 112, 1)

# %%
test = autoencoder.predict(data_noise_drop)

# %%
plt.imshow(data_noise_drop[0,:,:,0],cmap='gray')

# %%
plt.imshow(test[0,:,:,0],cmap='gray')

# %%
plt.imshow(lungs[0,:,:,0],cmap='gray')

# %%
plt.plot(np.arange(0,112),data_noise_drop[0,40,:,0])

# %%
test[0,40,:,0].max()
# Out:
# 154.06224

# %%
plt.plot(np.arange(0,112),test[0,40,:,0])

# %%
plt.plot(np.arange(0,112),data[0,40,:,0])

# %%
plt.plot(np.arange(0,112),data[0,40,:,0]-test[0,40,:,0])

# %% [markdown]
# ## Type 02: Snow noise

# %% [markdown]
# ### **View**

# %%
data = lungs
data.max(), data_noise_snow.max()
# Out:
# (255, 255)

# %%
plt.imshow(data[0,:,:,0],cmap='gray')

# %%
plt.imshow(data_noise_snow[0,:,:,0],cmap='gray')

# %% [markdown]
# ### **Build model**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(data_noise_snow,lungs,test_size=0.25,random_state=42)

# %%
EPOCHS = 100
BS = 5
(encoder, decoder, autoencoder) = dae_build(data[0].shape,activation='relu')
# autoencoder = dae_build(data[0].shape[0],data[0].shape[1],data[0].shape[2])
opt = Adam(lr=1e-3)
autoencoder.compile(loss="mse", optimizer=opt)
# train the convolutional autoencoder
H = autoencoder.fit(
	xtrain, ytrain,
	validation_data=(xtest, ytest),
	epochs=EPOCHS,
	batch_size=BS)
# construct a plot that plots and saves the training history
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
# Out:
# Epoch 1/100
# 270/270 [==============================] - 4s 13ms/step - loss: 2135.7280 - val_loss: 637.4869
# Epoch 2/100
# 270/270 [==============================] - 3s 12ms/step - loss: 552.9395 - val_loss: 564.2587
# Epoch 3/100
# 270/270 [==============================] - 3s 12ms/step - loss: 383.8224 - val_loss: 306.0023
# Epoch 4/100
# 270/270 [==============================] - 3s 12ms/step - loss: 261.2416 - val_loss: 207.4835
# Epoch 5/100
# 270/270 [==============================] - 3s 12ms/step - loss: 191.0272 - val_loss: 157.6169
# Epoch 6/100
# 270/270 [==============================] - 3s 12ms/step - loss: 145.3513 - val_loss: 132.7784
# Epoch 7/100
# 270/270 [==============================] - 3s 12ms/step - loss: 108.2030 - val_loss: 90.1604
# Epoch 8/100
# 270/270 [==============================] - 3s 12ms/step - loss: 75.2181 - val_loss: 67.3533
# Epoch 9/100
# 270/270 [==============================] - 3s 12ms/step - loss: 56.3325 - val_loss: 54.1063
# Epoch 10/100
# 270/270 [==============================] - 3s 12ms/step - loss: 38.8178 - val_loss: 33.1511
# Epoch 11/100
# 270/270 [==============================] - 3s 12ms/step - loss: 30.2576 - val_loss: 60.4908
# Epoch 12/100
# 270/270 [==============================] - 3s 12ms/step - loss: 34.2572 - val_loss: 20.1662
# Epoch 13/100
# 270/270 [==============================] - 3s 12ms/step - loss: 16.6644 - val_loss: 13.1314
# Epoch 14/100
# 270/270 [==============================] - 3s 12ms/step - loss: 13.9364 - val_loss: 12.7668
# Epoch 15/100
# 270/270 [==============================] - 3s 12ms/step - loss: 11.7872 - val_loss: 11.1363
# Epoch 16/100
# 270/270 [==============================] - 3s 12ms/step - loss: 9.9553 - val_loss: 9.8918
# Epoch 17/100
# 270/270 [==============================] - 3s 12ms/step - loss: 8.3331 - val_loss: 14.2409
# Epoch 18/100
# 270/270 [==============================] - 3s 12ms/step - loss: 9.6714 - val_loss: 10.5523
# Epoch 19/100
# 270/270 [==============================] - 3s 12ms/step - loss: 9.8394 - val_loss: 8.4512
# Epoch 20/100
# 270/270 [==============================] - 3s 12ms/step - loss: 7.8002 - val_loss: 6.7078
# Epoch 21/100
# 270/270 [==============================] - 3s 12ms/step - loss: 6.0105 - val_loss: 5.4835
# Epoch 22/100
# 270/270 [==============================] - 3s 12ms/step - loss: 5.3516 - val_loss: 14.3492
# Epoch 23/100
# 270/270 [==============================] - 3s 12ms/step - loss: 27.9607 - val_loss: 14.7449
# Epoch 24/100
# 270/270 [==============================] - 3s 12ms/step - loss: 8.2601 - val_loss: 4.8711
# Epoch 25/100
# 270/270 [==============================] - 3s 12ms/step - loss: 4.4703 - val_loss: 3.2492
# Epoch 26/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.5030 - val_loss: 3.1356
# Epoch 27/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.3689 - val_loss: 3.2623
# Epoch 28/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.0368 - val_loss: 3.3624
# Epoch 29/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.5605 - val_loss: 7.6392
# Epoch 30/100
# 270/270 [==============================] - 3s 12ms/step - loss: 4.3171 - val_loss: 3.2692
# Epoch 31/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.3684 - val_loss: 7.5505
# Epoch 32/100
# 270/270 [==============================] - 3s 12ms/step - loss: 4.2214 - val_loss: 10.9724
# Epoch 33/100
# 270/270 [==============================] - 3s 12ms/step - loss: 7.7454 - val_loss: 8.8080
# Epoch 34/100
# 270/270 [==============================] - 3s 12ms/step - loss: 5.4159 - val_loss: 4.1658
# Epoch 35/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.3910 - val_loss: 2.9360
# Epoch 36/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.8523 - val_loss: 2.7690
# Epoch 37/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.5623 - val_loss: 2.5034
# Epoch 38/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.7829 - val_loss: 3.5972
# Epoch 39/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.0919 - val_loss: 5.7821
# Epoch 40/100
# 270/270 [==============================] - 3s 12ms/step - loss: 4.0721 - val_loss: 29.7388
# Epoch 41/100
# 270/270 [==============================] - 3s 12ms/step - loss: 21.4313 - val_loss: 6.8715
# Epoch 42/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.1210 - val_loss: 2.1020
# Epoch 43/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.7295 - val_loss: 1.3445
# Epoch 44/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.2060 - val_loss: 1.4243
# Epoch 45/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.1792 - val_loss: 1.6680
# Epoch 46/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.3124 - val_loss: 1.6763
# Epoch 47/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.5067 - val_loss: 2.3301
# Epoch 48/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.9673 - val_loss: 3.0969
# Epoch 49/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.4327 - val_loss: 4.1865
# Epoch 50/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.8434 - val_loss: 3.1496
# Epoch 51/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.1500 - val_loss: 2.4366
# Epoch 52/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.2475 - val_loss: 3.6138
# Epoch 53/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.5186 - val_loss: 2.9029
# Epoch 54/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.5104 - val_loss: 2.5401
# Epoch 55/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.7107 - val_loss: 2.1581
# Epoch 56/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.5080 - val_loss: 1.8137
# Epoch 57/100
# 270/270 [==============================] - 3s 13ms/step - loss: 1.9600 - val_loss: 2.5503
# Epoch 58/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.2155 - val_loss: 3.9593
# Epoch 59/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.4220 - val_loss: 2.5522
# Epoch 60/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.5667 - val_loss: 1.5977
# Epoch 61/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.2790 - val_loss: 3.5733
# Epoch 62/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.7178 - val_loss: 2.9425
# Epoch 63/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.6865 - val_loss: 1.7430
# Epoch 64/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.7434 - val_loss: 2.9261
# Epoch 65/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.5406 - val_loss: 1.6120
# Epoch 66/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.3433 - val_loss: 1.8019
# Epoch 67/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.6014 - val_loss: 1.9510
# Epoch 68/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.4050 - val_loss: 1.3671
# Epoch 69/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.3955 - val_loss: 1.7110
# Epoch 70/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.4564 - val_loss: 2.1497
# Epoch 71/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.6297 - val_loss: 2.5118
# Epoch 72/100
# 270/270 [==============================] - 3s 12ms/step - loss: 2.3199 - val_loss: 2.5843
# Epoch 73/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.4327 - val_loss: 1.1433
# Epoch 74/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.9813 - val_loss: 0.9272
# Epoch 75/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.8604 - val_loss: 1.4954
# Epoch 76/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0690 - val_loss: 2.8850
# Epoch 77/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.3772 - val_loss: 1.4173
# Epoch 78/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0883 - val_loss: 1.0517
# Epoch 79/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.1190 - val_loss: 1.9350
# Epoch 80/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.3517 - val_loss: 1.1823
# Epoch 81/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0028 - val_loss: 1.1744
# Epoch 82/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.1346 - val_loss: 1.5063
# Epoch 83/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.4054 - val_loss: 2.7337
# Epoch 84/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.8843 - val_loss: 1.4627
# Epoch 85/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.8895 - val_loss: 1.4585
# Epoch 86/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.9386 - val_loss: 1.4596
# Epoch 87/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.8891 - val_loss: 1.0850
# Epoch 88/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.9261 - val_loss: 1.4788
# Epoch 89/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0851 - val_loss: 2.9579
# Epoch 90/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0698 - val_loss: 1.1511
# Epoch 91/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.3076 - val_loss: 1.1683
# Epoch 92/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0577 - val_loss: 3.8399
# Epoch 93/100
# 270/270 [==============================] - 3s 12ms/step - loss: 3.9611 - val_loss: 1.2164
# Epoch 94/100
# 270/270 [==============================] - 3s 12ms/step - loss: 1.0560 - val_loss: 0.6396
# Epoch 95/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.5255 - val_loss: 0.5644
# Epoch 96/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.4846 - val_loss: 0.8085
# Epoch 97/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.7094 - val_loss: 1.0372
# Epoch 98/100
# 270/270 [==============================] - 3s 13ms/step - loss: 0.6128 - val_loss: 1.2864
# Epoch 99/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.8293 - val_loss: 0.9514
# Epoch 100/100
# 270/270 [==============================] - 3s 12ms/step - loss: 0.8595 - val_loss: 0.9687

# %%
# autoencoder.save('./model/model_01_relu_e100.h5')

# %% [markdown]
# ### **View resualt**

# %%
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 112, 112, 1)]     0
# _________________________________________________________________
# encoder (Functional)         (None, 256)               12864512
# _________________________________________________________________
# decoder (Functional)         (None, 112, 112, 1)       12951297
# =================================================================
# Total params: 25,815,809
# Trainable params: 25,815,425
# Non-trainable params: 384
# _________________________________________________________________

# %%
test = autoencoder.predict(data_noise_snow[:10])

# %%
abnormal = data_noise_snow[:10]-test

# %%
test.max()
# Out:
# 263.77707

# %%
plt.imshow(data_noise_snow[3, :,:,0],cmap='gray')

# %%
plt.imshow(test[3, :,:,0],cmap='gray')

# %%
amax = abnormal[3,:,:,0].max()
amin = abnormal[3,:,:,0].min()
amax, amin, amax-amin
# Out:
# (205.23228, -60.07235, 265.30463)

# %%
plt.imshow(abnormal[3,:,:,0],cmap='gray')

# %%
plt.plot(np.arange(0,112),test[3,60,:,0])

# %%
plt.plot(np.arange(0,112),data[3,60,:,0])

# %%
plt.plot(np.arange(0,112),data_noise_snow[3,60,:,0])

# %%
plt.plot(np.arange(0,112),data_noise_snow[3,60,:,0]-data[3,60,:,0])

# %%
plt.plot(np.arange(0,112),data[3,60,:,0]-test[3,60,:,0])

# %%
plt.plot(np.arange(0,112),data_noise_snow[3,60,:,0]-test[3,60,:,0])

# %%
plt.imshow(lungs[3, :,:,0],cmap='gray')
